# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import ollama
ollama.list()
# Out:
# {'models': [{'name': 'llama3:latest',
#    'model': 'llama3:latest',
#    'modified_at': '2024-05-10T14:59:44.2482721+09:00',
#    'size': 4661224578,
#    'digest': 'a6990ed6be412c6a217614b0ec8e9cd6800a743d5dd7e1d7fbe9df09e61d5615',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '8B',
#     'quantization_level': 'Q4_0'}}]}

# %%
import pandas as pd

file_path = "./prepro_company_data.csv"
df = pd.read_csv(file_path)
df["Positive_Score"] = None
df
# Out:
#       company     code        Date  \
# 0        삼성전자  '005930  2021-03-12
# 1        삼성전자  '005930  2021-03-05
# 2        삼성전자  '005930  2021-05-14
# 3        삼성전자  '005930  2021-02-05
# 4        삼성전자  '005930  2021-01-22
# ...       ...      ...         ...
# 15895   코오롱인더  '120110  2023-07-21
# 15896   코오롱인더  '120110  2023-10-20
# 15897   코오롱인더  '120110  2023-10-27
# 15898   코오롱인더  '120110  2023-12-01
# 15899   코오롱인더  '120110  2023-12-29
#
#                                                   Title Positive_Score
# 0                    진짜 5 G 28 서비스 활성화 첫 발 과기부 TF 발족 회의           None
# 1                                  아버님 댁 에어 프라이어 놓다 드리다           None
# 2                             ESG 경영 첫 단추 늘다 여성 관리자 키우다           None
# 3                      삼성 공장 증설 19조 투자 주 정부 9000억 세제 요청           None
# 4                        화웨이 서다 분리 중 가폰 어너 인텔 삼성 반도체 계약           None
# ...                                                 ...            ...
# 15895                    연구개발 1.1조 쏟다 코오롱 인 더 하반기 과실 딴다           None
# 15896  코오롱 인 더 3 Q 영업 익 시장 기 대치 회 4 Q 패션 성 수기 효과 기대 IBK           None
# 15897             코오롱 몰다 파격 할인 2023 OLO 모드 K 쇼핑 위 크다 진행           None
# 15898             추다 날씨 아우 터 판매 확대 코오롱 인 더 실적 개선 전망 IBK           None
# 15899                뉴 재계 34 세지 분 승계 만 남다 코오롱 이규호 시대 개막           None
#
# [15900 rows x 5 columns]

# %%
import pandas as pd
import re
import os
import ollama
import time

# CSV 파일 경로
file_path = "./LLAMA3-8B-CL.csv"

# 파일 존재 여부 확인 및 초기화
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
else:
    df = pd.DataFrame(columns=['Title', 'company', 'Positive_Score'])  # 기본적인 컬럼을 가진 빈 DataFrame 생성
    df.to_csv(file_path, index=False, encoding='utf-8-sig')  # 빈 파일을 생성하여 저장

model = "llama3:latest"

df2 = pd.read_csv("./KR-Finbert.csv")

# 시스템 명령 정의
system_instruction = "금융전문가로 가정해주세요. 당신은 주식 추천 경험이 있는 금융 전문가입니다."

# 감성 분석 및 점수 저장
while True:
    try:
        for idx, row in df.iterrows():
            title = row['Title']
            company = row['company']
            positive_score_from_df2 = df2.loc[df2['Title'] == title, 'Positive_Score'].values[0]
            
            # 'Positive_Score' 값이 이미 있는 경우 건너뛰기
            if pd.notnull(row['Positive_Score']):
                continue
            
            print(f"Processing headline {idx}: {title}")
            
            # 사용자 프롬프트 생성
            user_prompt = f"헤드라인: {title}. 좋은 뉴스, 나쁜 뉴스, 불확실한 뉴스 세 가지가 될 확률이 합쳐서 1일 때 좋은 뉴스일 정도를 확률로만 답변해주세요. (예시답변: 0.2) {company}에 좋은 영향을 숫자로만 답해주세요. KR-FinBERT의 'Positive_Score'는 {positive_score_from_df2}입니다"
            
            # ollama 모델을 사용하여 응답 받기
            response = ollama.chat(model=model, messages=[
                {"role": "system", "content": system_instruction},  # 시스템 명령 추가
                {"role": "user", "content": user_prompt}
            ])
            
            # 응답에서 숫자만 추출하여 저장
            score = re.findall(r'\d+\.\d+', response['message']['content'])
            if score:
                df.at[idx, 'Positive_Score'] = float(score[0])
                df.to_csv(file_path, index=False, encoding='utf-8-sig')  # 점수를 CSV 파일에 저장
            else:
                print(f"No score found for headline {idx}")
        
        break  # 에러 없이 완료되었으면 반복문 종료
    
    except Exception as e:
        print(f"An error occurred: {str(e)}. Retrying in 1 minute...")
        time.sleep(60)  # 1분 대기 후 다시 시도

print("감성 분석이 완료되었습니다.")
# Out:
# Processing headline 0: 진짜 5 G 28 서비스 활성화 첫 발 과기부 TF 발족 회의
# Processing headline 1: 아버님 댁 에어 프라이어 놓다 드리다
# Processing headline 2: ESG 경영 첫 단추 늘다 여성 관리자 키우다
# Processing headline 3: 삼성 공장 증설 19조 투자 주 정부 9000억 세제 요청
# Processing headline 4: 화웨이 서다 분리 중 가폰 어너 인텔 삼성 반도체 계약
# Processing headline 5: 삼성 갤폴드 3 갤플 립 3 이렇게 나오다 .. 시장 경쟁 본격 화
# Processing headline 6: 제품 차단 반사 이익 ... 사드 악몽 엔 선제 적 대비 나서다
# Processing headline 7: 최태원 SK 회장 ESG 경영 정보 량 1 위
# Processing headline 8: 지갑 병풍 ... S 펜 품다 삼성 폴 더블 폰 특허 눈길
# Processing headline 9: 고공 행진 코스피 블루 웨이브 애플 호재 3100 도 돌파
# Processing headline 10: 삼성 준법 위 이재용 취업 제한 관련 법령 준수 권고
# Processing headline 11: 역대 급 한파 삼성 LG 기아 롯데 국내 기업 피해 속출
# Processing headline 12: 카툭 튀다 사라지다 .. 1만 배 얇다 메타 렌즈 개발
# Processing headline 13: 손경 식 경 총 회장 이재용 사면 공식 건의 반도체 위기 대응 하다
# Processing headline 14: 삼성 SDI 디스플레이 삼성 줄줄이 7 대다 임금 인상
# Processing headline 15: 지난해 국내 서다 5 G 쓰다 사람 1200만 명 육박
# Processing headline 16: 공급망 재 구축 삼성 역할 절실 하다 투자 당근 책 내미다 수도
# Processing headline 17: 이재용 부회장 선처 해달라다 박용만 대다 하다 상의 회장 법원 탄원서
# Processing headline 18: 이건희 지다 분 상속세 홍라희 3.1조 이재용 2.9조
# Processing headline 19: 삼성 주 총 안건 국민연금 수탁 위 패싱 논란 기 금위 미흡하다 인정
# Processing headline 20: 한화 3 남 김동선 승마 대회 서다 우승
# Processing headline 21: SK 하이닉스 인텔 낸드 사업 인수 .. 중국 태클 걸다
# Processing headline 22: 홍 남다 대기업 선도 적 역할 중요 투자 일자리 창 추다 당부
# Processing headline 23: 캐논 브라질 공장 폐쇄 결정 판매 기술 지원 은 유지
# Processing headline 24: 삼성 5 번째 SW 아카데미 부울경 캠퍼스 열다 연간 200 명 취업 지원 종합
# Processing headline 25: 삼성 현대차 SKLG 44조원 투자 보따리 풀다
# Processing headline 26: 오다 댓 차이나 화웨이 올해 스마트폰 매출 최대 400억 감소
# Processing headline 27: 삼성 글로벌 기업 매출 올리다 국가 에도 세금 내야
# Processing headline 28: 지겹다 조기 테이퍼링 분석 ... 풋 락커 실적 테슬라 AI 데이 평가 주목 뉴욕 증 ...
# Processing headline 29: 오다 댓 차이나 통신 기기 화웨이 상반기 매출 29% ... 스마트폰 타격 종합 ...
# Processing headline 30: 흙 수저 김범수 이재용 치고 최고 부자
# Processing headline 31: IBK 기업은행 직원 권 익 보호 관 이현주 전 한국인 성 컨설팅 이사 임용
# Processing headline 32: 삼성 SW 아카데미 6 기 950 명 지원 취업률 70% 돌파 종합
# Processing headline 33: 김 새다 삼성 신형 폴 더블 폰 대거 유출
# Processing headline 34: 폴 더블 아니다 헐값 개다 S 20 울트라 159만 40만원
# Processing headline 35: 삼바 찾다 김 총리 백 신 주권 삼성 역할 기대
# Processing headline 36: 샤오미 작정 하다 재 뿌리다 삼성 이다 애플 언 팩 직전 제품 내놓다
# Processing headline 37: 코스피 1% 삼성 5% 하이닉스 9% 종목 46% 뛰다
# Processing headline 38: 젠 일본 기업 도 갤폴드 따르다 후지필름 판박이 제품 특허 출원
# Processing headline 39: 가짜 뉴스 사다 물리다 동진 쎄다 밉다 켐 상한 급락
# Processing headline 40: 카카오 12만원 회복하다 고민 되다 증권사 목표 주가 줄줄이 하향
# Processing headline 41: 정부 7일 미국 반도체 자료 요구 요 소수 대책 논의
# Processing headline 42: 한국 제품 알다 중국 삼성 홀 대다 0% 충격
# Processing headline 43: 삼성 3분 기 매출 사상 첫 70조원 돌파
# Processing headline 44: 상무부 SK 하이닉스 인텔 반도체 자료 제공 하다
# Processing headline 45: 반도체 여행 햇살 자동차 구름 주택 공급 부족 집값 상승세
# Processing headline 46: 2년 전 오다 오다 관람객 기 대다 만발 친환경 SK 부스 가보다 CES 20 ...
# Processing headline 47: 영상 CES 2022 서도 기업 주인공 혁신 상 대거 수상
# Processing headline 48: 거 진짜 예쁘다 아이폰 만 살다 미국 반한 삼성
# Processing headline 49: 고맙다 삼성 . 덕분 타도 벤츠 제네시스 별 전쟁 승기 잡다 ...
# Processing headline 50: 하다 우즈베키스탄 비즈니스 라운드 테이블
# Processing headline 51: 리틀 건희 이부진 세계 영향력 있다 여성 89 위 한국 유일 톱 100
# Processing headline 52: 영상 삼성 주도 8 K 연합 아마존 합류 .. 8 K 판 커지다
# Processing headline 53: 삼성 창사 53년 만에 첫 파업 가나 노조 노동 쟁의 조정 신청 종합
# Processing headline 54: 회식 금지 재택근무 확대 오미크론 놀란 기업 방역 지침 강화
# Processing headline 55: 영상 전자부품 양대 산맥 삼성 전기 LG 이노 텍 ... 올해 승자 늘다
# Processing headline 56: 영상 성 폰 27만원 .. 가성 비 깡패 폰 갤럭시 XCover 5
# Processing headline 57: 작년 세계 스마트폰 시장 4년 만에 반등 삼성 1 위
# Processing headline 58: 해외 서다 무슬림 여장남자 등장 광고 하다 성전 진땀
